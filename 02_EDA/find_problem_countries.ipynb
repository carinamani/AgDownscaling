# %%
##### Search through results from RF models to identify countries which are repeatidly a problem 
# major problem countries may be excluded from RF training 

import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib.patches as mpatches

# %%
##### Load data

# Get the current working directory
cd = os.path.dirname(os.getcwd())

# Import model data
capital_model_tonne = pd.read_csv(f"{cd}/Results/RF_models/capital_tonne_rtv_rf_sqrt_inverse/country_metrics.csv")
capital_model_USD = pd.read_csv(f"{cd}/Results/RF_models/capital_USD_rtv_rf_sqrt_inverse/country_metrics.csv")
labor_model_tonne = pd.read_csv(f"{cd}/Results/RF_models/labor_tonne_rtv_rf_sqrt_inverse/country_metrics.csv")
labor_model_USD = pd.read_csv(f"{cd}/Results/RF_models/labor_USD_rtv_rf_sqrt_inverse/country_metrics.csv")

# %%
##### Get country averages 

capital_model_tonne_avg = capital_model_tonne.groupby(['country', 'split'])[['r2', 'rmse']].mean().reset_index()
capital_model_USD_avg = capital_model_USD.groupby(['country', 'split'])[['r2', 'rmse']].mean().reset_index()
labor_model_tonne_avg = labor_model_tonne.groupby(['country', 'split'])[['r2', 'rmse']].mean().reset_index()
labor_model_USD_avg = labor_model_USD.groupby(['country', 'split'])[['r2', 'rmse']].mean().reset_index()
