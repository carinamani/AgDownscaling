# %%
##### Cleans China capital stock data
# does basic calculation and reformats

import os
import pandas as pd

# %%
##### Load data

# Get the current working directory
cd = os.path.dirname(os.getcwd())

# Import data
capital = pd.read_csv(f"{cd}/Data/Raw/Mexico/fixed_assets_municipality.csv")

MEX_codes = pd.read_csv(f"{cd}/Data/Correspondence_tables/MEX_municipalities.csv", encoding="latin1")

# Set save path
save_path = f"{cd}/Data/Clean/Capital_stock/MEX_capital_stock_Census.csv"

# %%
##### Clean capital stock

# keep only agricultre
capital_stock = capital[capital['Sector'] == 'Agricultura, Cría y Explotación de Animales, Aprovechamiento Forestal, Pesca y Caza']

# convert to USD using average annual exchange rate for 2014 (https://www.exchangerates.org.uk/MXN-USD-spot-exchange-rates-history-2014.html)
USD_per_MEX_2014 = 1 / 0.0752
capital_stock['2014'] = (capital_stock['Total_fixed_assets']/USD_per_MEX_2014) * 1e6

# add units
capital_stock['Units'] = 'Ag capital stock - USD (nominal)'

# re-order columns
columns_to_keep = ['Municipality_ID', 'Units', '2014']
capital_stock = capital_stock[columns_to_keep]
# Out:
# /var/folders/48/ky2jtbmj31bfj15cr5gq480w0000gn/T/ipykernel_81160/389005242.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   capital_stock['2014'] = (capital_stock['Total_fixed_assets']/USD_per_MEX_2014) * 1e6
# /var/folders/48/ky2jtbmj31bfj15cr5gq480w0000gn/T/ipykernel_81160/389005242.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   capital_stock['Units'] = 'Ag capital stock - USD (nominal)'

# %%
# Save cleaned data
capital_stock.to_csv(save_path, index=False)
