# %%
##### Cleans South Africa labor and capital stock data
# cleans, combines regions, and reformats

import os
import pandas as pd
import lxml
import numpy as np
import geopandas as gpd
import rasterio
from rasterio.features import rasterize
from rasterio.transform import from_bounds
from rasterio.warp import reproject, Resampling
import rasterstats
from rasterstats import zonal_stats

# %%
##### Load data

# Get the current working directory
cd = os.path.dirname(os.getcwd())

# Import data
def load_stats_sa_html(path):
    tables = pd.read_html(path)
    return tables[0]

Eastern_Cape = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Eastern Cape Financial and production statistics.xls")
Free_State = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Free State Financial and production statistics.xls")
Gauteng = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Gauteng Financial and production statistics.xls")
KwaZulu_Natal = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Kwa-Zulu Natal Financial and production statistics.xls")
Limpopo = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Limpopo Financial and production statistics.xls")
Mpumalanga = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Mpumalanga Financial and production statistics.xls")
North_West = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture North West Financial and production statistics.xls")
Northern_Cape = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Northern Cape Financial and production statistics.xls")
Western_Cape = load_stats_sa_html(f"{cd}/Data/Raw/Sub_National/South_Africa/Census of commercial agriculture Western Cape Financial and production statistics.xls")

ZAF_codes = pd.read_csv(f"{cd}/Data/Correspondence_tables/ZAF_municipalities.csv")

ZAF_municipalities = gpd.read_file('/Users/carinamanitius/Documents/Data/Admin_Boundaries/South_Africa_municipalities/ZAF_municipalities.shp')

ag_production = f"{cd}/Data/Clean/Production/total_production_USD_2020.tif"

# Set save path
save_path_capital = f"{cd}/Data/Clean/Capital_stock/ZAF_capital_stock.csv"
save_path_labor = f"{cd}/Data/Clean/Labor/ZAF_labor.csv"

# %%
##### Clean data

# append all provinces
South_Africa = pd.concat([Eastern_Cape, Free_State, Gauteng, KwaZulu_Natal, Limpopo, Mpumalanga, North_West, Northern_Cape, Western_Cape], ignore_index=True)

# drop unneeded variables
vars_to_keep = [
    'Family members involved in agricultural activities',
    'Paid employees',
    'Dryers for agricultural products',
    'Harvesters',
    'Mechanical appliances for chemical application',
    'Milking and dairy machines',
    'Other machinery and equipment for farming purposes',
    'Poultry-keeping machinery',
    'Presses and crushes and similar machinery',
    'Tractors'
]

South_Africa = South_Africa[South_Africa['H06'].isin(vars_to_keep)]

# drop if province or enterprise data
South_Africa = South_Africa.dropna(subset=['H04'])
South_Africa = South_Africa[South_Africa['H05'] != 99]

# drop gender data
South_Africa = South_Africa[South_Africa['H07'] != 'Male']
South_Africa = South_Africa[South_Africa['H07'] != 'Female']

# %%
##### Split into capital and labor

labor_var = ['Family members involved in agricultural activities', 'Paid employees']
capital_var = ['Dryers for agricultural products',
    'Harvesters',
    'Mechanical appliances for chemical application',
    'Milking and dairy machines',
    'Other machinery and equipment for farming purposes',
    'Poultry-keeping machinery',
    'Presses and crushes and similar machinery',
    'Tractors']

labor = South_Africa[South_Africa['H06'].isin(labor_var)]
capital_stock = South_Africa[South_Africa['H06'].isin(capital_var)]

# %%
##### Final clean

# sum by municipality 
labor_sum = labor.groupby('H04')['Y2017'].sum().reset_index()
capital_stock_sum = capital_stock.groupby('H04')['Y2017'].sum().reset_index()

# rename columns
labor_sum.rename(columns={'Y2017': '2017'}, inplace=True)
capital_stock_sum.rename(columns={'Y2017': '2017'}, inplace=True)
labor_sum.rename(columns={'H04': 'ADMN3_NAME'}, inplace=True)
capital_stock_sum.rename(columns={'H04': 'ADMN3_NAME'}, inplace=True)

# add units
capital_stock_sum['Units'] = 'Ag capital stock - count of tractors, machinery, and equipment'
labor_sum['Units'] = 'Ag labor - jobs'

# add geography codes
capital_stock_sum = capital_stock_sum.merge(ZAF_codes, on='ADMN3_NAME', how='inner')
labor_sum = labor_sum.merge(ZAF_codes, on='ADMN3_NAME', how='inner')

# re-order columns
capital_to_keep = ['CC_3', 'Units', '2017']
capital_stock_sum = capital_stock_sum[capital_to_keep]

labor_to_keep = ['CC_3', 'Units', '2017']
labor_sum = labor_sum[labor_to_keep]

# %%
### Final cleaning 

labor_sum['ISO3'] = 'ZAF'
labor_sum['Year'] = 2017
labor_sum['GEO_ID_NAME'] = 'CC_3'

labor_sum = labor_sum.rename(columns={'2017': 'ag_labor_jobs', 'CC_3': 'GEO_ID'})

col_to_keep = ['ISO3', 'GEO_ID', 'GEO_ID_NAME', 'Year', 'ag_labor_jobs']
labor_sum = labor_sum[col_to_keep]


capital_stock_sum['ISO3'] = 'ZAF'
capital_stock_sum['Year'] = 2017
capital_stock_sum['GEO_ID_NAME'] = 'CC_3'

capital_stock_sum = capital_stock_sum.rename(columns={'2017': 'ag_capital_stock_count_machinery', 'CC_3': 'GEO_ID'})

col_to_keep = ['ISO3', 'GEO_ID', 'GEO_ID_NAME', 'Year', 'ag_capital_stock_count_machinery']
capital_stock_sum = capital_stock_sum[col_to_keep]

# %%
##### Fill missing state data (CAPITAL)

### 1: identify missing states 
ZAF_municipalities_cap = ZAF_municipalities.merge(capital_stock_sum, left_on='CC_3', right_on='GEO_ID', how='left')

ZAF_municipalities_missing = ZAF_municipalities_cap[ZAF_municipalities_cap['ag_capital_stock_count_machinery'].isna()].copy()
ZAF_municipalities_filled  = ZAF_municipalities_cap[ZAF_municipalities_cap['ag_capital_stock_count_machinery'].notna()].copy()

### 2: calculate the total ag production in each state
def subnational_production_stats(geo, raster_path, column_name, nodata=-9999):

    with rasterio.open(raster_path) as src:
        raster_crs = src.crs

    # ensure crs match
    gdf_proj = geo.to_crs(raster_crs)

    zonal = rasterstats.zonal_stats(
        gdf_proj,
        raster_path,
        stats="sum",
        nodata=nodata
    )

    geo[column_name] = [z["sum"] for z in zonal]
    return geo

ZAF_municipalities_missing_prod = subnational_production_stats(ZAF_municipalities_missing, ag_production, "total_production_USD")
ZAF_municipalities_filled_prod = subnational_production_stats(ZAF_municipalities_filled, ag_production, "total_production_USD")

### 3: Get the average machinery per $ for filled data
ZAF_municipalities_filled_prod = ZAF_municipalities_filled_prod.dropna()
machinery_total_count = ZAF_municipalities_filled_prod['ag_capital_stock_count_machinery'].sum()
production_total_USD = ZAF_municipalities_filled_prod['total_production_USD'].sum()

machinery_per_USD = machinery_total_count / production_total_USD

### 4: use machinery per $ to fill missing data
ZAF_municipalities_missing_prod['ag_capital_stock_count_machinery'] = machinery_per_USD * ZAF_municipalities_missing_prod['total_production_USD']

### 5: recombine
ZAF_municipalities_cap = pd.concat([ZAF_municipalities_filled_prod, ZAF_municipalities_missing_prod])

# %%
##### Fill missing state data (LABOR)

### 1: identify missing states 
ZAF_municipalities_lab = ZAF_municipalities.merge(labor_sum, left_on='CC_3', right_on='GEO_ID', how='left')

ZAF_municipalities_lab_missing = ZAF_municipalities_lab[ZAF_municipalities_lab['ag_labor_jobs'].isna()].copy()
ZAF_municipalities_lab_filled  = ZAF_municipalities_lab[ZAF_municipalities_lab['ag_labor_jobs'].notna()].copy()

### 2: calculate the total ag production in each state
def subnational_production_stats(geo, raster_path, column_name, nodata=-9999):

    with rasterio.open(raster_path) as src:
        raster_crs = src.crs

    # ensure crs match
    gdf_proj = geo.to_crs(raster_crs)

    zonal = rasterstats.zonal_stats(
        gdf_proj,
        raster_path,
        stats="sum",
        nodata=nodata
    )

    geo[column_name] = [z["sum"] for z in zonal]
    return geo

ZAF_municipalities_lab_missing_prod = subnational_production_stats(ZAF_municipalities_lab_missing, ag_production, "total_production_USD")
ZAF_municipalities_lab_filled_prod = subnational_production_stats(ZAF_municipalities_lab_filled, ag_production, "total_production_USD")

### 3: Get the average machinery per $ for filled data
ZAF_municipalities_lab_filled_prod = ZAF_municipalities_lab_filled_prod.dropna()
total_jobs = ZAF_municipalities_lab_filled_prod['ag_labor_jobs'].sum()
production_total_USD = ZAF_municipalities_lab_filled_prod['total_production_USD'].sum()

jobs_per_USD = total_jobs / production_total_USD

### 4: use machinery per $ to fill missing data
ZAF_municipalities_lab_missing_prod['ag_labor_jobs'] = jobs_per_USD * ZAF_municipalities_lab_missing_prod['total_production_USD']

### 5: recombine
ZAF_municipalities_lab = pd.concat([ZAF_municipalities_lab_filled_prod, ZAF_municipalities_lab_missing_prod])

# %%
### Clean back to final format 
col_to_keep = ['ISO3', 'CC_3', 'GEO_ID_NAME', 'Year', 'ag_capital_stock_count_machinery']
ZAF_municipalities_cap = ZAF_municipalities_cap[col_to_keep]

ZAF_municipalities_cap['ag_capital_stock_count_machinery'] = ZAF_municipalities_cap['ag_capital_stock_count_machinery'].fillna(0)
ZAF_municipalities_cap['ISO3'] = ZAF_municipalities_cap['ISO3'].fillna('ZAF')
ZAF_municipalities_cap['GEO_ID_NAME'] = ZAF_municipalities_cap['GEO_ID_NAME'].fillna('CC_3')
ZAF_municipalities_cap['Year'] = ZAF_municipalities_cap['Year'].fillna(2017)

ZAF_municipalities_cap = ZAF_municipalities_cap.rename(columns={'CC_3': 'GEO_ID'})


col_to_keep = ['ISO3', 'CC_3', 'GEO_ID_NAME', 'Year', 'ag_labor_jobs']
ZAF_municipalities_lab = ZAF_municipalities_lab[col_to_keep]

ZAF_municipalities_lab['ag_labor_jobs'] = ZAF_municipalities_lab['ag_labor_jobs'].fillna(0)
ZAF_municipalities_lab['ISO3'] = ZAF_municipalities_lab['ISO3'].fillna('ZAF')
ZAF_municipalities_lab['GEO_ID_NAME'] = ZAF_municipalities_lab['GEO_ID_NAME'].fillna('CC_3')
ZAF_municipalities_lab['Year'] = ZAF_municipalities_lab['Year'].fillna(2017)

ZAF_municipalities_lab = ZAF_municipalities_lab.rename(columns={'CC_3': 'GEO_ID'})

# %%
##### Save cleaned data
ZAF_municipalities_lab.to_csv(save_path_labor, index=False)
ZAF_municipalities_cap.to_csv(save_path_capital, index=False)
