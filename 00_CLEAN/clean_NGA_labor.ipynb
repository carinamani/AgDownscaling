# %%
##### Cleans Nigeria labor data
# cleans and reformats (not using informal workers because not all countries' data includes that)

import os
import pandas as pd

# %%
##### Load data

# Get the current working directory
cd = os.path.dirname(os.getcwd())

# Import data
labor = pd.read_csv(f"{cd}/Data/Raw/Sub_National/Nigeria/NGA_employment.csv")

NGA_states = pd.read_csv(f"{cd}/Data/Correspondence_tables/NGA_states.csv")

# Set save path
save_path = f"{cd}/Data/Clean/Labor/NGA_labor.csv"

# %%
##### Clean

# rename column 
labor = labor.rename(columns={'employed_in_ag': '2023'})

# add units
labor['Units'] = 'Ag labor - jobs'

# keep only neccesary columns
col_to_keep = ['HASC_1', 'Units', '2023']
labor = labor[col_to_keep]

# %%
### Final cleaning 

labor['ISO3'] = 'NGA'
labor['Year'] = 2023
labor['GEO_ID_NAME'] = 'HASC_1'

labor = labor.rename(columns={'2023': 'ag_labor_jobs', 'HASC_1': 'GEO_ID'})

col_to_keep = ['ISO3', 'GEO_ID', 'GEO_ID_NAME', 'Year', 'ag_labor_jobs']
labor = labor[col_to_keep]

# %%
##### Save
labor.to_csv(save_path, index=False)
